# %% [markdown]
# ## Simple CNN 2
# This CNN varies from the first CNN by adding Dropout layers before and after the Dense layer. We also tried increasing the image resolution to 256x256.

# %%
# %run ../data_preparation.ipynb
# Out:
# Number of finding labels: 16297
# Complete

# %%
# Splitting data into training and validation sets.
from sklearn.model_selection import train_test_split
training_df, validation_df = train_test_split(xray_labels_df, 
                                              test_size = 0.25, 
                                              random_state = 2018,
                                              stratify = xray_labels_df['Finding Labels'].map(lambda x: x[:4]))

print('train', training_df.shape[0], 'validation', validation_df.shape[0])
# Out:
# train 9000 validation 3000

# %%
from keras.preprocessing.image import ImageDataGenerator
IMG_SIZE = (256, 256)
core_idg = ImageDataGenerator(samplewise_center=True,
                              samplewise_std_normalization=True,
                              horizontal_flip=True,
                              vertical_flip=True,
                              height_shift_range=0.05,
                              width_shift_range=0.1,
                              rotation_range=5,
                              shear_range=0.1,
                              fill_mode='reflect',
                              zoom_range=0.15)

# %%
# Generates training and validation data to be used by models.
# Lowered batch size so that we can run this on a GPU.
training_gen = flow_from_dataframe(core_idg, training_df, path_col='path', y_col='disease_vec',target_size = IMG_SIZE, color_mode ='grayscale', batch_size = 16)
validation_gen = flow_from_dataframe(core_idg, validation_df, path_col='path', y_col='disease_vec',target_size = IMG_SIZE, color_mode ='grayscale', batch_size = 128)

test_X, test_Y = next(flow_from_dataframe(core_idg, validation_df, path_col ='path', y_col ='disease_vec', target_size = IMG_SIZE, color_mode = 'grayscale', batch_size = 1024))

t_x, t_y = next(training_gen)
# Out:
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 9000 images
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 3000 images
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 3000 images

# %%
from keras.applications.mobilenet import MobileNet
from keras.layers import GlobalAveragePooling2D, Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.models import Sequential
import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

multi_disease_model = Sequential()
multi_disease_model.add(Conv2D(32, (3,3), input_shape=t_x.shape[1:], activation='relu'))
multi_disease_model.add(MaxPooling2D(pool_size = (2,2)))
multi_disease_model.add(Flatten())
multi_disease_model.add(Dropout(0.5))
multi_disease_model.add(Dense(32))
multi_disease_model.add(Dropout(0.5))
multi_disease_model.add(Dense(len(all_labels), activation = 'sigmoid'))
multi_disease_model.compile(optimizer = 'adam', loss ='binary_crossentropy',
                            metrics = ['binary_accuracy', 'mae'])
multi_disease_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 254, 254, 32)      320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 32)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 516128)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 516128)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                16516128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 16,516,679
# Trainable params: 16,516,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau

weight_path = "{}_weights_simpleCNN2_256x256.best.hdf5".format("xray_class")

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=10)

callbacks_list = [checkpoint, early]

# %%
multi_disease_model.fit_generator(training_gen, 
                                  steps_per_epoch=100,
                                  validation_data = (test_X, test_Y), 
                                  epochs = 1, 
                                  callbacks = callbacks_list)
# Out:
# Epoch 1/1
# 100/100 [==============================] - 57s 572ms/step - loss: 0.9423 - binary_accuracy: 0.9158 - mean_absolute_error: 0.1000 - val_loss: 0.3555 - val_binary_accuracy: 0.9388 - val_mean_absolute_error: 0.1363
#
# Epoch 00001: val_loss improved from inf to 0.35546, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5

# %%
multi_disease_model.load_weights(weight_path)
pred_Y = multi_disease_model.predict(test_X, batch_size = 32, verbose = True)
# Out:
# 1024/1024 [==============================] - 3s 3ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(all_labels):
    fpr, tpr, thresholds = roc_curve(test_Y[:,idx].astype(int), pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.plot(fpr, fpr, 'k-', label = 'Random Guessing')
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig('1epoch_simpleCNN2_256x256.png')

# %%
history = multi_disease_model.fit_generator(training_gen, 
                                            steps_per_epoch = 100,
                                            validation_data =  (test_X, test_Y), 
                                            epochs = 100, 
                                            callbacks = callbacks_list)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 57s 573ms/step - loss: 0.3604 - binary_accuracy: 0.9143 - mean_absolute_error: 0.1569 - val_loss: 0.2554 - val_binary_accuracy: 0.9386 - val_mean_absolute_error: 0.1090
#
# Epoch 00001: val_loss improved from 0.35546 to 0.25536, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 2/100
# 100/100 [==============================] - 63s 629ms/step - loss: 0.3006 - binary_accuracy: 0.9166 - mean_absolute_error: 0.1510 - val_loss: 0.2353 - val_binary_accuracy: 0.9386 - val_mean_absolute_error: 0.1145
#
# Epoch 00002: val_loss improved from 0.25536 to 0.23526, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 3/100
# 100/100 [==============================] - 67s 668ms/step - loss: 0.2762 - binary_accuracy: 0.9204 - mean_absolute_error: 0.1425 - val_loss: 0.2295 - val_binary_accuracy: 0.9383 - val_mean_absolute_error: 0.1272
#
# Epoch 00003: val_loss improved from 0.23526 to 0.22946, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 4/100
# 100/100 [==============================] - 106s 1s/step - loss: 0.2618 - binary_accuracy: 0.9273 - mean_absolute_error: 0.1360 - val_loss: 0.2315 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1345
#
# Epoch 00004: val_loss did not improve
# Epoch 5/100
# 100/100 [==============================] - 100s 997ms/step - loss: 0.2553 - binary_accuracy: 0.9338 - mean_absolute_error: 0.1340 - val_loss: 0.2352 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.0874
#
# Epoch 00005: val_loss did not improve
# Epoch 6/100
# 100/100 [==============================] - 83s 827ms/step - loss: 0.2543 - binary_accuracy: 0.9308 - mean_absolute_error: 0.1327 - val_loss: 0.2234 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1258
#
# Epoch 00006: val_loss improved from 0.22946 to 0.22341, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 7/100
# 100/100 [==============================] - 53s 532ms/step - loss: 0.2452 - binary_accuracy: 0.9346 - mean_absolute_error: 0.1299 - val_loss: 0.2170 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1127
#
# Epoch 00007: val_loss improved from 0.22341 to 0.21695, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 8/100
# 100/100 [==============================] - 59s 590ms/step - loss: 0.2348 - binary_accuracy: 0.9368 - mean_absolute_error: 0.1235 - val_loss: 0.2189 - val_binary_accuracy: 0.9389 - val_mean_absolute_error: 0.1075
#
# Epoch 00008: val_loss did not improve
# Epoch 9/100
# 100/100 [==============================] - 67s 673ms/step - loss: 0.2500 - binary_accuracy: 0.9351 - mean_absolute_error: 0.1312 - val_loss: 0.2174 - val_binary_accuracy: 0.9389 - val_mean_absolute_error: 0.1092
#
# Epoch 00009: val_loss did not improve
# Epoch 10/100
# 100/100 [==============================] - 96s 959ms/step - loss: 0.2357 - binary_accuracy: 0.9374 - mean_absolute_error: 0.1243 - val_loss: 0.2151 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1059
#
# Epoch 00010: val_loss improved from 0.21695 to 0.21506, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 11/100
# 100/100 [==============================] - 102s 1s/step - loss: 0.2426 - binary_accuracy: 0.9317 - mean_absolute_error: 0.1286 - val_loss: 0.2178 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1228
#
# Epoch 00011: val_loss did not improve
# Epoch 12/100
# 100/100 [==============================] - 63s 633ms/step - loss: 0.2270 - binary_accuracy: 0.9383 - mean_absolute_error: 0.1207 - val_loss: 0.2272 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1451
#
# Epoch 00012: val_loss did not improve
# Epoch 13/100
# 100/100 [==============================] - 58s 578ms/step - loss: 0.2352 - binary_accuracy: 0.9367 - mean_absolute_error: 0.1273 - val_loss: 0.2152 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1190
#
# Epoch 00013: val_loss did not improve
# Epoch 14/100
# 100/100 [==============================] - 61s 614ms/step - loss: 0.2224 - binary_accuracy: 0.9406 - mean_absolute_error: 0.1161 - val_loss: 0.2142 - val_binary_accuracy: 0.9389 - val_mean_absolute_error: 0.1189
#
# Epoch 00014: val_loss improved from 0.21506 to 0.21425, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 15/100
# 100/100 [==============================] - 75s 751ms/step - loss: 0.2281 - binary_accuracy: 0.9397 - mean_absolute_error: 0.1231 - val_loss: 0.2266 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.0862
#
# Epoch 00015: val_loss did not improve
# Epoch 16/100
# 100/100 [==============================] - 94s 937ms/step - loss: 0.2328 - binary_accuracy: 0.9362 - mean_absolute_error: 0.1249 - val_loss: 0.2126 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1066
#
# Epoch 00016: val_loss improved from 0.21425 to 0.21263, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 17/100
# 100/100 [==============================] - 98s 983ms/step - loss: 0.2288 - binary_accuracy: 0.9388 - mean_absolute_error: 0.1220 - val_loss: 0.2146 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1213
#
# Epoch 00017: val_loss did not improve
# Epoch 18/100
# 100/100 [==============================] - 47s 466ms/step - loss: 0.2341 - binary_accuracy: 0.9360 - mean_absolute_error: 0.1262 - val_loss: 0.2139 - val_binary_accuracy: 0.9389 - val_mean_absolute_error: 0.1216
#
# Epoch 00018: val_loss did not improve
# Epoch 19/100
# 100/100 [==============================] - 49s 493ms/step - loss: 0.2263 - binary_accuracy: 0.9388 - mean_absolute_error: 0.1213 - val_loss: 0.2117 - val_binary_accuracy: 0.9389 - val_mean_absolute_error: 0.1096
#
# Epoch 00019: val_loss improved from 0.21263 to 0.21167, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 20/100
# 100/100 [==============================] - 55s 549ms/step - loss: 0.2253 - binary_accuracy: 0.9396 - mean_absolute_error: 0.1188 - val_loss: 0.2187 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1356
#
# Epoch 00020: val_loss did not improve
# Epoch 21/100
# 100/100 [==============================] - 63s 633ms/step - loss: 0.2187 - binary_accuracy: 0.9401 - mean_absolute_error: 0.1176 - val_loss: 0.2132 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1036
#
# Epoch 00021: val_loss did not improve
# Epoch 22/100
# 100/100 [==============================] - 100s 1s/step - loss: 0.2211 - binary_accuracy: 0.9401 - mean_absolute_error: 0.1181 - val_loss: 0.2113 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1084
#
# Epoch 00022: val_loss improved from 0.21167 to 0.21129, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 23/100
# 100/100 [==============================] - 74s 739ms/step - loss: 0.2166 - binary_accuracy: 0.9412 - mean_absolute_error: 0.1155 - val_loss: 0.2167 - val_binary_accuracy: 0.9388 - val_mean_absolute_error: 0.0951
#
# Epoch 00023: val_loss did not improve
# Epoch 24/100
# 100/100 [==============================] - 50s 496ms/step - loss: 0.2206 - binary_accuracy: 0.9407 - mean_absolute_error: 0.1190 - val_loss: 0.2149 - val_binary_accuracy: 0.9388 - val_mean_absolute_error: 0.1001
#
# Epoch 00024: val_loss did not improve
# Epoch 25/100
# 100/100 [==============================] - 56s 561ms/step - loss: 0.2217 - binary_accuracy: 0.9404 - mean_absolute_error: 0.1171 - val_loss: 0.2116 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1179
#
# Epoch 00025: val_loss did not improve
# Epoch 26/100
# 100/100 [==============================] - 60s 597ms/step - loss: 0.2251 - binary_accuracy: 0.9386 - mean_absolute_error: 0.1219 - val_loss: 0.2120 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1224
#
# Epoch 00026: val_loss did not improve
# Epoch 27/100
# 100/100 [==============================] - 85s 852ms/step - loss: 0.2182 - binary_accuracy: 0.9358 - mean_absolute_error: 0.1203 - val_loss: 0.2151 - val_binary_accuracy: 0.9388 - val_mean_absolute_error: 0.1046
#
# Epoch 00027: val_loss did not improve
# Epoch 28/100
# 100/100 [==============================] - 119s 1s/step - loss: 0.2199 - binary_accuracy: 0.9390 - mean_absolute_error: 0.1190 - val_loss: 0.2104 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1107
#
# Epoch 00028: val_loss improved from 0.21129 to 0.21038, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 29/100
# 100/100 [==============================] - 54s 541ms/step - loss: 0.2174 - binary_accuracy: 0.9403 - mean_absolute_error: 0.1155 - val_loss: 0.2112 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1179
#
# Epoch 00029: val_loss did not improve
# Epoch 30/100
# 100/100 [==============================] - 45s 447ms/step - loss: 0.2178 - binary_accuracy: 0.9396 - mean_absolute_error: 0.1175 - val_loss: 0.2100 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1131
#
# Epoch 00030: val_loss improved from 0.21038 to 0.21002, saving model to xray_class_weights_simpleCNN2_256x256.best.hdf5
# Epoch 31/100
# 100/100 [==============================] - 49s 489ms/step - loss: 0.2268 - binary_accuracy: 0.9367 - mean_absolute_error: 0.1281 - val_loss: 0.2127 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1194
#
# Epoch 00031: val_loss did not improve
# Epoch 32/100
# 100/100 [==============================] - 54s 543ms/step - loss: 0.2124 - binary_accuracy: 0.9413 - mean_absolute_error: 0.1149 - val_loss: 0.2108 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1041
#
# Epoch 00032: val_loss did not improve
# Epoch 33/100
# 100/100 [==============================] - 77s 772ms/step - loss: 0.2075 - binary_accuracy: 0.9411 - mean_absolute_error: 0.1111 - val_loss: 0.2109 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1132
#
# Epoch 00033: val_loss did not improve
# Epoch 34/100
# 100/100 [==============================] - 82s 819ms/step - loss: 0.2140 - binary_accuracy: 0.9373 - mean_absolute_error: 0.1154 - val_loss: 0.2134 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1021
#
# Epoch 00034: val_loss did not improve
# Epoch 35/100
# 100/100 [==============================] - 40s 397ms/step - loss: 0.2149 - binary_accuracy: 0.9384 - mean_absolute_error: 0.1141 - val_loss: 0.2113 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1104
#
# Epoch 00035: val_loss did not improve
# Epoch 36/100
# 100/100 [==============================] - 43s 430ms/step - loss: 0.2103 - binary_accuracy: 0.9403 - mean_absolute_error: 0.1119 - val_loss: 0.2126 - val_binary_accuracy: 0.9386 - val_mean_absolute_error: 0.1060
#
# Epoch 00036: val_loss did not improve
# Epoch 37/100
# 100/100 [==============================] - 47s 475ms/step - loss: 0.2148 - binary_accuracy: 0.9392 - mean_absolute_error: 0.1126 - val_loss: 0.2106 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1094
#
# Epoch 00037: val_loss did not improve
# Epoch 38/100
# 100/100 [==============================] - 53s 533ms/step - loss: 0.2096 - binary_accuracy: 0.9396 - mean_absolute_error: 0.1125 - val_loss: 0.2110 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1088
#
# Epoch 00038: val_loss did not improve
# Epoch 39/100
# 100/100 [==============================] - 77s 767ms/step - loss: 0.2116 - binary_accuracy: 0.9404 - mean_absolute_error: 0.1103 - val_loss: 0.2107 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1083
#
# Epoch 00039: val_loss did not improve
# Epoch 40/100
# 100/100 [==============================] - 64s 637ms/step - loss: 0.2148 - binary_accuracy: 0.9404 - mean_absolute_error: 0.1120 - val_loss: 0.2105 - val_binary_accuracy: 0.9390 - val_mean_absolute_error: 0.1081
#
# Epoch 00040: val_loss did not improve

# %%
multi_disease_model.load_weights('xray_class_weights_simpleCNN2_256x256.best.hdf5')
pred_Y = multi_disease_model.predict(test_X, batch_size = 32, verbose = True)
# Out:
# 1024/1024 [==============================] - 5s 5ms/step

# %%
from sklearn.metrics import roc_curve, auc
fig, c_ax = plt.subplots(1,1, figsize = (9, 9))
for (idx, c_label) in enumerate(all_labels):
    fpr, tpr, thresholds = roc_curve(test_Y[:,idx].astype(int), pred_Y[:,idx])
    c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
c_ax.plot(fpr, fpr, 'k-', label = 'Random Guessing')
c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
fig.savefig('40epoch_simpleCNN2_256x2562.png')

# %%
sickest_idx = np.argsort(np.sum(test_Y, 1)<1)
fig, m_axs = plt.subplots(2, 4, figsize = (8, 6))
for (idx, c_ax) in zip(sickest_idx, m_axs.flatten()):
    c_ax.imshow(test_X[idx, :,:,0], cmap = 'bone')
    stat_str = [n_class[:6] for n_class, n_score in zip(all_labels, 
                                                                  test_Y[idx]) 
                             if n_score>0.5]
    pred_str = ['%s:%2.0f%%' % (n_class[:4], p_score*100)  for n_class, n_score, p_score in zip(all_labels, 
                                                                  test_Y[idx], pred_Y[idx]) 
                             if (n_score>0.5) or (p_score>0.5)]
    c_ax.set_title('Dx: '+', '.join(stat_str)+'\nPDx: '+', '.join(pred_str))
    c_ax.axis('off')
fig.savefig('trained_img_predictions_256x256_simpleCNN2.png')

# %%
plt.figure(1, figsize = (16,5))
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='lower right')

# %%
plt.figure(1, figsize = (16,5))
plt.subplot(211)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper right')
